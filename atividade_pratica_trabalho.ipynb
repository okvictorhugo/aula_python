# %% [markdown]
# <a href="https://colab.research.google.com/github/okvictorhugo/aula_python/blob/main/atividade_pratica_trabalho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Bem vindo a loja do Victor Hugo RU:4183052')

valorProduto = float(input('Pode nos informar o valor do produto?: '))
qtdProduto = int(input('Por gentileza, pode nos informar a quantidade escolhida: '))
subtotal = valorProduto * qtdProduto
if 0 <= qtdProduto < 4: # sem o desconto
  valorFinal = subtotal
elif 5 <= qtdProduto < 19:
  valorFinal = subtotal - subtotal * 0.03 # desconto de 3%
elif 20 <= qtdProduto < 99:
  valorFinal = subtotal - subtotal * 0.06 # desconto de 6%
else: # se a qtd for acima de 99 entra nesse else
  valorFinal = subtotal - subtotal * 0.10 # desconto de 10%


print('O valor sem desconto: R$ {:.2f}'.format(subtotal))
print('O valor com o desconto: R$ {:.2f}'.format(valorFinal))
# Out:
# Bem vindo a loja do Victor Hugo RU:4183052
# Pode nos informar o valor do produto?: 50
# Por gentileza, pode nos informar a quantidade escolhida: 10
# O valor sem desconto: R$ 500.00
# O valor com o desconto: R$ 485.00

# %%
print('Bem vindo a Pizzaria do Victor Hugo')

print('Aqui está o cardápio:')


print('=====================Cardápio do dia=====================')

print('| Código | | Descrição | | Pizza Média | | Pizza Grande |')

print('|   21   | |Napolitana | |   R$20,00   | |    R$26,00   |')

print('|   22   | |Margherita | |   R$20,00   | |    R$26,00   |')

print('|   23   | |Calabresa  | |   R$25,00   | |    R$32,50   |')

print('|   24   | |Toscana    | |   R$30,00   | |    R$39,00   |')

print('|   25   | |Portuguesa | |   R$30,00   | |    R$39,00   |')

print('=========================================================')

total = 0

while True:
  tamanho = input('Qual o tamanho da pizza que deseja (M/G)?: ')
  if (tamanho == 'M'):
    precos = [20,20,25,30,30]
  elif (tamanho == 'G'):
    precos = [26,26,32.50,39,39]
  else:
    # opcao invalida se for digitado um numero fora da tabela
    print('Opcao invalida')
    continue #volta para o comeco

  codigo = int(input('Entre com o codigo do sabor desejado: '))
  if (codigo == 21):
    print('Voce pediu uma pizza Napolitana')
    total += precos[0]
  elif (codigo == 22):
    print('Voce pediu uma pizza Margherita')
    total += precos[1]
  elif (codigo == 23):
    print('Voce pediu uma pizza Calabresa')
    total += precos[2]
  elif (codigo == 24):
    print('Voce pediu uma pizza Toscana')
    total += precos[3]
  elif (codigo == 25):
    print('Voce pediu uma pizza Portuguesa')
    total += precos[4]
  else:
      # opcao invalida caso o numero nao exista na tabela
    print('Opcao Invalida')
    continue #volta
      
  repetir = int(input('Deseja pedir mais alguma coisa? \n1 - Sim\n0 - Nao\n>>'))
  if (repetir==1):
    continue
  else:
      #valor total
    print('O total a ser pago é: R${:.2f}'.format(total))
    break
# Out:
# Bem vindo a Pizzaria do Victor Hugo
# Aqui está o cardápio:
# =====================Cardápio do dia=====================
# | Código | | Descrição | | Pizza Média | | Pizza Grande |
# |   21   | |Napolitana | |   R$20,00   | |    R$26,00   |
# |   22   | |Margherita | |   R$20,00   | |    R$26,00   |
# |   23   | |Calabresa  | |   R$25,00   | |    R$32,50   |
# |   24   | |Toscana    | |   R$30,00   | |    R$39,00   |
# |   25   | |Portuguesa | |   R$30,00   | |    R$39,00   |
# ...
# Qual o tamanho da pizza que deseja (M/G)?: M
# Entre com o codigo do sabor desejado: 28
# Opcao Invalida
# Qual o tamanho da pizza que deseja (M/G)?: F
# Opcao invalida
# Qual o tamanho da pizza que deseja (M/G)?: M
# Entre com o codigo do sabor desejado: 22
# Voce pediu uma pizza Margherita
# Deseja pedir mais alguma coisa?
# 1 - Sim
# 0 - Nao
# >>0
# O total a ser pago é: R$20.00

# %%
print('Bem vindo ao Programa de Feijoada do Victor Hugo \n')

#volume feijoada
def volumeFeijoada ():
  # loop para verificar se o volume e valido 
  
  while True:
    print('Menu Volume Feijoada')
    while True:
      try:
        volume = float(input('Entre com a quantidade que deseja em (ml): '))
      except ValueError:
        print('Foi inserido um valor nao numerico')
        print('Por favor, entre com o volume novamente')
        continue
      break

    if 300 <= volume <= 5000:
      valor = volume * 0.08
    else:
       print('Nao aceitamos porcoes menores do que 300ml ou maiores do que 5l. Tente novamente!')
       continue
    break
  
  return valor

  #opcao feijoada
def opcaoFeijoada ():
  while True:
    print('Menu Opcao Feijoada')
    print('Entre com a opcao de Feijoada: ')
    print('b- Basica (Feijao + paiol + costelinha)')
    print('p- Premium (Feijao + paiol + costelinha + partes de porco)')
    print('s- Suprema (Feijao + paiol + costelinha + partes de porco + charque + calabresa + bacon)')
    opcao = input('>> ')

# if, elif e else para multiplicador
    if (opcao == 'b'):
      multiplicador = 1.00
    elif (opcao == 'p'):
      multiplicador = 1.25
    elif (opcao == 's'):
      multiplicador = 1.50
    else:
      print('Voce nao digitou uma opcao valida')
      continue
    break

  return multiplicador

  # acompanhamento feijoada
def acompanhamentoFeijoada ():
  #armazenar o total do adicional
  adicional = 0
  while True:
    print('Deseja mais algum acompanhamento?: ')
    print('0- nao deseja mais algum acompanhamento (encerrar pedido)')
    print('1- 200g de arroz')
    print('2- 150g de farofa especial')
    print('3- 100g de couve')
    print('4- 1 laranja descascada')
    acompanhamento = int(input('>> '))

  #if, elif e esle para a tabela
    if (acompanhamento == 0):
      break
    elif (acompanhamento == 1):
      adicional += 5
      continue
    elif (acompanhamento == 2):
      adicional += 6
      continue
    elif (acompanhamento == 3):
      adicional += 7
      continue
    elif (acompanhamento == 4):
      adicional += 3
      continue
    else:
      print('Voce nao digitou uma opcao valida')
      continue

  return adicional

  # aramazenar as saidas
volume = volumeFeijoada ()
opcao = opcaoFeijoada ()
adicional = acompanhamentoFeijoada ()

 # calculo do valor total

total = (volume*opcao) + adicional
print('O valor a ser pago é R$: {:.2f} (volume = {:.2f} * opcao = {:.2f} + acompanhamento = {:.2f})'.format(total, volume, opcao, adicional))
print('Obrigado pela preferencia!')
# Out:
# Bem vindo ao Programa de Feijoada do Victor Hugo
#
# Menu Volume Feijoada
# Entre com a quantidade que deseja em (ml): grande
# Foi inserido um valor nao numerico
# Por favor, entre com o volume novamente
# Entre com a quantidade que deseja em (ml): 300
# Menu Opcao Feijoada
# Entre com a opcao de Feijoada:
# b- Basica (Feijao + paiol + costelinha)
# p- Premium (Feijao + paiol + costelinha + partes de porco)
# s- Suprema (Feijao + paiol + costelinha + partes de porco + charque + calabresa + bacon)
# >> a
# Voce nao digitou uma opcao valida
# Menu Opcao Feijoada
# Entre com a opcao de Feijoada:
# b- Basica (Feijao + paiol + costelinha)
# p- Premium (Feijao + paiol + costelinha + partes de porco)
# s- Suprema (Feijao + paiol + costelinha + partes de porco + charque + calabresa + bacon)
# >> b
# Deseja mais algum acompanhamento?:
# 0- nao deseja mais algum acompanhamento (encerrar pedido)
# 1- 200g de arroz
# 2- 150g de farofa especial
# 3- 100g de couve
# 4- 1 laranja descascada
# ...

# %%
print('Bem vindo ao Controle de Estoque da Mercearia do Victor Hugo!\n')

#cadastrar produto
def cadastrarProduto(codigo):
  nome = input('Por favor, entre com o NOME do produto: ')
  fabricante = input('Por favor, entre com o FABRICANTE do produto: ')
  valor = float(input('Por favor, entre com o VALOR (R$) do produto: '))

  return nome, fabricante, valor

# consultar produto
def consultarProduto(codigo,nome,fabricante,valor):
  #loop para exibir as opcoes e executar operacoes ate que volte a opcao Retornar
  while True:
    print('Escolha a opcao desejada:')
    print('1-Consultar Todas os Produtos')
    print('2-Consultar Produtos por Codigo')
    print('3-Consultar Produtos por Fabricante')
    print('4-Retornar')
    opcao = int(input('>> '))
    n = len(codigo)

    if (opcao == 1):
      print('--------------------')
      for i in range(n):
        print('Codigo: {}'.format(codigo[i]))
        print('Nome: {}'.format(nome[i]))
        print('Fabricante: {}'.format(fabricante[i]))
        print('Valor: R$ {:.2f}'.format(valor[i]))
      print('--------------------')

    elif (opcao == 2):
      produtoProcurado = int(input('Digite o CODIGO do Produto: '))
      # buscar a posicao relacionada ao interesse
      contador = 0
      for i in range(n):
        if (produtoProcurado == codigo[i]):
          contador += 1
          print('--------------------')
          print('Codigo: {}'.format(codigo[i]))
          print('Nome: {}'.format(nome[i]))
          print('Fabricante: {}'.format(fabricante[i]))
          print('Valor: R$ {:.2f}'.format(valor[i]))
          print('--------------------')
          break
        if (contador==0):
          print('Codigo nao cadastrado')

    elif (opcao == 3):
      produtoProcurado = input('Digite o FABRICANTE do Produto: ')
      # encontrar as posicoes relacionadas ao fabricante
      contador = 0
      print('--------------------')
      for i in range(n):
        if (produtoProcurado == fabricante[i]):
          contador += 1
          print('--------------------')
          print('Codigo: {}'.format(codigo[i]))
          print('Nome: {}'.format(nome[i]))
          print('Fabricante: {}'.format(fabricante[i]))
          print('Valor: R$ {:.2f}'.format(valor[i]))
      print('--------------------')
      if (contador==0):
          print('Fabricante nao cadastrado')

    elif (opcao == 4):
      break

    else:
      continue

# funcao remover produto
def removerProduto():

  CodigoRemover = int(input('Digite o codigo do Produto a ser removida:'))
  CodigoRemover -= 1

  #remover valores ao codigo informado em todas as listas
  del(codigo[CodigoRemover])
  del(nome[CodigoRemover])
  del(fabricante[CodigoRemover])
  del(valor[CodigoRemover])


#variaveis principais
contador = 0
codigo = []
nome = []
fabricante = []
valor = []

# loop para executar as funcoes ate que se escolha a opcao Sair
while True:
  print('Escolha a opcao desejada:')
  print('1-Cadastrar Produtos')
  print('2-Consultar Produto(s)')
  print('3-Remover Produtos')
  print('4-Sair')
  option = int(input('>> '))

  if (option == 1):
    print('Voce selecionou a opcao de Cadastrar Produto(s)')
    contador += 1
    print('Codigo do Produto(s): 00{}'.format(contador))
    novoNome, novoFabricante, novoValor = cadastrarProduto(contador)
    # adiciona informacoes a lista ja existente
    codigo.append(contador)
    nome.append(novoNome)
    fabricante.append(novoFabricante)
    valor.append(novoValor)

  elif (option == 2):
    print('Voce selecionou a opcao de consultar Produto(s)')
    consultarProduto(codigo,nome,fabricante,valor)

  elif (option == 3):
    print('Voce selecionou a opcao de remover Produto(s)')
    removerProduto()

  elif (option == 4):
    print('Obrigado pela preferencia!')
    break

  else:
    print('Opcao invalida')
    continue
# Out:
# Bem vindo ao Controle de Estoque da Mercearia do Victor Hugo!
#
# Escolha a opcao desejada:
# 1-Cadastrar Produtos
# 2-Consultar Produto(s)
# 3-Remover Produtos
# 4-Sair
# >> 1
# Voce selecionou a opcao de Cadastrar Produto(s)
# Codigo do Produto(s): 001
# Por favor, entre com o NOME do produto: Caneta Azul
# Por favor, entre com o FABRICANTE do produto: Bic
# Por favor, entre com o VALOR (R$) do produto: 1.99
# Escolha a opcao desejada:
# 1-Cadastrar Produtos
# 2-Consultar Produto(s)
# 3-Remover Produtos
# 4-Sair
# >> 1
# Voce selecionou a opcao de Cadastrar Produto(s)
# Codigo do Produto(s): 002
# Por favor, entre com o NOME do produto: Caneta Preta
# Por favor, entre com o FABRICANTE do produto: Bic
# Por favor, entre com o VALOR (R$) do produto: 1.99
# Escolha a opcao desejada:
# 1-Cadastrar Produtos
# 2-Consultar Produto(s)
# 3-Remover Produtos
# 4-Sair
# >> 1
# Voce selecionou a opcao de Cadastrar Produto(s)
# Codigo do Produto(s): 003
# ...
